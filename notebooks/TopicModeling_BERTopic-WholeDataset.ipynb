# %% [markdown]
# ## Load required libraries

# %%
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm
from collections import Counter
import nltk
from bertopic import BERTopic
import torch
import re
import altair as alt
from nltk.corpus import stopwords
import os
from IPython.display import display, HTML
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import warnings
warnings.filterwarnings('ignore')
seed=696

# %% [markdown]
# #### Define Paths to be Used

# %%
# Read articles for 2004 for test purpose
basepath = '../'
filepath = 'datasets/'
# filepath_name = basepath + filepath + filename
path = basepath + filepath

model_path = '../model_extract/ModelTrainedOn3pcData/'
train_file = 'train_df_3pc.csv'
model = 'bertopic_model_3pc'

# %% [markdown]
# ### Choose Run Type - Model Training/Use Saved Model

# %%
model_trained = str(input())
# Out:
# Y

# %% [markdown]
# ## Required Utilities

# %% [markdown]
# ### Text Pre-processing Utilities

# %%
allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']
# nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', \
                   'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need',  \
                   'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])

def utils_preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (convert to lowercase and remove punctuations and characters and then strip)
    lst_text = text.split()
    ## choose only alphbetical words and filter words less than 3 chars
    lst_text = [token.lower() for token in lst_text if token.isalpha() and len(token) >=3]      
#     text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
            
    ## Tokenize (convert from string to list)
#     lst_text = text.split()
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
    
    lst_text = [token for token in lst_text if len(token) >=3]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

def lemmatization(texts, allowed_postags=allowed_postags):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return(texts_out)

# %% [markdown]
# ### Train/Test Split Utility

# %%
# divides the articles in to train/test by splitting on year/month basis 
def split_data(path, sample_size, random_state=696):
    # list all the files in diectory
    files = sorted(os.listdir(path))
    columns = ['id', 'date','article']
    train_df = pd.DataFrame({'id': [], 'date': [],'article': []}) 
    test_df = pd.DataFrame({'id': [], 'date': [], 'article': []}) 
    for indx, file in enumerate(files[:2]):
            file_path = path + file
            print(file_path)
            articles_df = pd.read_json(file_path, lines=True)
            articles_df = articles_df.dropna()    
            articles_df['date'] = pd.to_datetime(articles_df['date'])
            articles_df['month'] = articles_df['date'].dt.month
            num_months = 12
            yr_sample_df = pd.DataFrame({'id': [], 'date': [], 'article': []})
            for month in range(num_months):                
                month_df = articles_df.loc[articles_df['month'] == month + 1]
                size = round(len(month_df) * sample_size/100)  
                month_df = month_df.sample(size, random_state=random_state)
#                 print(month+1, len(month_df), size)                
                month_df = month_df.loc[: , columns]
                yr_sample_df = pd.concat([yr_sample_df, month_df], ignore_index=False)
            
            # choose remaining docs for topic inference
            yr_test_df = articles_df.loc[~articles_df['id'].isin(yr_sample_df.id)]
            print(len(yr_sample_df), len(yr_test_df), len(articles_df))
            
            train_df = pd.concat([train_df, yr_sample_df], ignore_index=True) 
            train_df = train_df.dropna()
            test_df = pd.concat([test_df, yr_test_df], ignore_index=False)
    return(train_df, test_df)

# %% [markdown]
# ### Model Exploration Utilities

# %%
def topic_top_term(model):
    topic_list = list(model.get_topics().keys())
    top_terms_list = []
    for topic_id, term_prob in model.get_topics().items():
        terms = [term for term,prob in term_prob]
        top_terms_list.append( str(topic_id) + '_'+ ' '.join(terms))
    df = pd.DataFrame(list(zip(topic_list, top_terms_list)), columns=['topic_id', 'top_terms'])
    return(df)

def get_top_terms(topic_id):
    top_term_prob_lst = topic_model.get_topic(topic_id)
    top_terms = [term for
                 term,prob in top_term_prob_lst]
    return(' '.join(top_terms))


def topic_inference(basepath, model_path, model):
    prob_threshold=0.05
    files = sorted(os.listdir(path))
    files = [file for file in files if ".jl" in file]
    for file in tqdm(files):
        filepath = path + file
        yr_df = pd.read_json(filepath, lines=True)
        yr_df = yr_df.dropna().reset_index(drop=True)
        yr_df['clean_text'] = yr_df['article'].apply(lambda text : 
                                utils_preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=stop_words))
        texts = list(yr_df['clean_text'].values)
        topics, probs = model.transform(texts)    
        
        new_topics = [np.argmax(prob) if max(prob) >= prob_threshold else -1 for prob in probs ]
        print('topic inference done for file:', file)
        
        yr_df['topic_id'] = new_topics
        yr_df['top_topics'],yr_df['top_probs'] = zip(*yr_df.apply(lambda x : get_top_5_topics(x.name, probs), axis=1)) 
        
        columns = ['id', 'date', 'topic_id', 'top_topics', 'top_probs']
        yr_df = yr_df.loc[:, columns]
        yr_df['id'] = yr_df['id'].astype('int32')
        yr_df['topic_id'] = yr_df['topic_id'].astype('int')
        filename = file[:13] + '.csv'
        filepath = model_path  + filename
        yr_df.to_csv( filepath)
        print('processing done for file:', file)
        
def get_top_5_topics(idx, probs):
    ind = np.argpartition(probs[idx], -5)[-5:]
    top_topics = list(ind[np.argsort(probs[idx][ind])[::-1]])
    top_probs = [round(prob, 6) for prob in probs[idx][top_topics]]
    return(top_topics, top_probs)

# %% [markdown]
# ## Load Data

# %%
# split the news articles in train/test
# this train dataset would be used to train the BERTopic model from which topic inference can be done
if  model_trained != 'Y':
    train_df, test_df = split_data(path, 3)

    filepath = model_path + train_file
    train_df.to_csv(filepath)

# %% [markdown]
# ### Pre-processing Text

# %%
# %%time
if  model_trained != 'Y':
    train_df['clean_text'] = train_df['article'].apply(lambda text : 
                            utils_preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=stop_words))

    train_df.head()

# %%
if model_trained == 'Y':
    filepath = model_path + train_file
    train_df = pd.read_csv(filepath, usecols=['id','date','article','clean_text','topic_id','topic_prob','top_terms'])
    train_df.head()

# %% [markdown]
# ### Train model for 3% articles

# %% [markdown]
# ### Create Model

# %%
# choosing number of articles to process for stub testing
texts = list(train_df['clean_text'].values)

# %%
# %%time
if model_trained != 'Y':
    topic_model = BERTopic(language='english', calculate_probabilities=True,
                               verbose=True, nr_topics=100)
    topics, probs = topic_model.fit_transform(texts)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs

# %% [markdown]
# ### Load Trained Model for Future Runs

# %%
if model_trained == 'Y':
    topic_model = torch.load(model_path + model)
    topics = topic_model.topics_
    probs = topic_model.probabilities_

# %%
# get topic id and correspodning top topic terms     
top_term_df = topic_top_term(topic_model)
top_term_df
# Out:
#      topic_id                                          top_terms
# 0          -1  -1_said police government state one people min...
# 1           0  0_student school education teacher class colle...
# 2           1  1_police suicide body murder found family arre...
# 3           2  2_bjp party candidate congress leader seat ele...
# 4           3  3_railway train passenger station metro rail e...
# ..        ...                                                ...
# 96         95  95_drug medicine pharma generic chemist pharma...
# 97         96  96_cattle cow animal bull slaughter stray meat...
# 98         97  97_militant killed grenade security terrorist ...
# 99         98  98_currency atm note bank fake cash counterfei...
# 100        99  99_event student dance fest college cultural f...
#
# [101 rows x 2 columns]

# %% [markdown]
# ### Get Document - Topic(dominant) mapping

# %%
# create document and top topic term mapping 
topics = train_df['topic_id'].values
train_df['topic_id'] = topics
train_df['topic_prob'] = train_df.apply(lambda x : probs[x.name][x.topic_id], axis=1)
train_df['top_terms'] = train_df['topic_id'].apply(lambda topic_id : get_top_terms(topic_id)) 

train_df.head(3)
# Out:
#        id        date                                            article  \
# 0  4379.0  2004-01-24  NEW DELHI: A high-level BJP meeting here on Fr...
# 1  1792.0  2004-01-12  PUNE: Sugar factories controlled by deputy chi...
# 2   749.0  2004-01-06  KOLKATA/HOWRAH: In a bid to cover up the mess,...
#
#                                           clean_text  topic_id  topic_prob  \
# 0  new bjp meeting friday gave official seal appr...         2    0.181298
# 1  sugar factory controlled deputy chief minister...        21    0.046529
# 2  bid cover state government monday set inquiry ...        25    0.037723
#
#                                            top_terms
# 0  bjp party candidate congress leader seat elect...
# 1  farmer crop sugar agriculture sugarcane paddy ...
# 2  land housing estate developer property flat re...

# %% [markdown]
# ### Topic-Term Matrix

# %%
num_topics = len(topic_model.get_topic_info())-1
topic_list = list(range(num_topics))
num_topics
# Out:
# 100

# %%
def get_topic_term_matrix(model, df):
    num_topics = len(model.get_topic_info())-1
    topic_list = list(range(num_topics))
    top_term_list = []
    rep_docs_list = []
    url_list = []
    articles_list = []
    for topic_id in topic_list:    
        top_term_prob_lst = model.get_topic(topic_id)
        top_terms = [term for term,prob in top_term_prob_lst]        
        top_term_list.append(top_terms)
        doc = model.get_representative_docs(topic_id)[0]
        df = df[df.clean_text == doc]
        rep_docs_list.append(doc)    

    df = pd.DataFrame({'topic_id': topic_list, 'top_terms':top_term_list, 'rep_docs': rep_docs_list})
    return(df)

dom_topic_doc_df = get_topic_term_matrix(topic_model, train_df)
dom_topic_doc_df.to_csv('dom_topic_doc_df_whole.csv')
dom_topic_doc_df.iloc[11, :].rep_docs
# display(HTML(dom_topic_doc_df.to_html()))
# Out:
# 'maker gujarati film sawaal question approached film certification appellate tribunal central board film certification denied certificate rajesh director gujarati said approached fcat july cbfc denied fight film freedom hope justice gohil june suggested cut questioned motive choosing emotive raised concern resemblance patel quota activist hardik pahlaj board denied certificate film stating film prove threat national security said cbfc suggested cut included removal word every board said content asked remove reference said edited film way cbfc wanted length film reduced minute current injustice gujarati film board hurt gohil'

# %% [markdown]
# ### Topic Distribution over documents

# %%
prob_threshold=0.01
new_topics = [np.argmax(prob) if max(prob) >= prob_threshold else -1 for prob in probs ]

topic_dist_df = pd.DataFrame(Counter(topics).items(), columns=['topic_id', 'Count'])
topic_dist_df = topic_dist_df.sort_values(by='topic_id')

# topic_dist_df
freq = topic_dist_df.merge(top_term_df, on='topic_id', how='inner')
freq = freq.sort_values(by='topic_id')
freq.head()
# Out:
#    topic_id  Count                                          top_terms
# 0        -1   3977  -1_said police government state one people min...
# 1         0   3668  0_student school education teacher class colle...
# 2         1   5135  1_police suicide body murder found family arre...
# 3         2   5411  2_bjp party candidate congress leader seat ele...
# 4         3   1112  3_railway train passenger station metro rail e...

# %%
base_chart = alt.Chart(freq.iloc[1:30, ])
bar = base_chart.mark_bar().encode(
        x=alt.X('top_terms:N',sort='-y', axis=alt.Axis(title='Topic ID')),
        y=alt.Y('Count:Q', axis=alt.Axis(title='Number of Articles')))

(bar
).properties(width=500, height=300, title='Topics vs Number of Article Distribution'
).configure_title(fontSize=25
).configure_axis(grid=False, domain=False, 
                 labelFontSize=15,titleFontSize=5)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Visualize Topic Distribution

# %%
# hierarchical_topics = topic_model.hierarchical_topics(texts)

# %% [markdown]
# ## Visualize Topic Distribution

# %%
topic_model.visualize_topics(top_n_topics=10)
# Out:
# <div>                            <div id="ac3eb75b-e445-4f87-b2b5-22e46705ca22" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac3eb75b-e445-4f87-b2b5-22e46705ca22")) {                    Plotly.newPlot(                        "ac3eb75b-e445-4f87-b2b5-22e46705ca22",                        [{"customdata": [[0, "student | school | education | teacher | class", 2867], [1, "police | suicide | body | murder | found", 2269], [2, "bjp | party | candidate | congress | leader", 1233], [3, "railway | train | passenger | station | metro", 1092], [4, " |  |  |  | ", 905], [5, "driver | accident | car | bus | truck", 841], [6, "water | supply | dam | drinking | pipeline", 786], [7, "music | song | singer | dance | classical", 773], [8, "girl | police | accused | raped | woman", 752], [9, "court | justice | bench | judge | high", 740]], "hovertemplate": "<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}", "legendgroup": "", "marker": {"color": "#B0BEC5", "line": {"color": "DarkSlateGrey", "width": 2}, "size": [2867, 2269, 1233, 1092, 905, 841, 786, 773, 752, 740], "sizemode": "area", "sizeref": 1.791875, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [26.895275115966797, -16.111425399780273, 7.573279857635498, 26.550241470336914, null, -16.249826431274414, 26.7289981842041, 27.350732803344727, -16.65333366394043, 7.308193206787109], "xaxis": "x", "y": [38.38574981689453, 16.421741485595703, -7.862941265106201, 38.80189895629883, null, 16.876188278198242, 39.29570007324219, 38.25640106201172, 16.338607788085938, -7.597846984863281], "yaxis": "y"}],                        {"annotations": [{"showarrow": false, "text": "D1", "x": -19.151333713531493, "y": 18.073836314678193, "yshift": 10}, {"showarrow": false, "text": "D2", "x": 6.151004505157472, "xshift": 10, "y": 45.19005508422852}], "height": 650, "hoverlabel": {"bgcolor": "white", "font": {"family": "Rockwell", "size": 16}}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"line": {"color": "#CFD8DC", "width": 2}, "type": "line", "x0": 6.151004505157472, "x1": 6.151004505157472, "y0": -9.042382454872131, "y1": 45.19005508422852}, {"line": {"color": "#9E9E9E", "width": 2}, "type": "line", "x0": -19.151333713531493, "x1": 31.453342723846436, "y0": 18.073836314678193, "y1": 18.073836314678193}], "sliders": [{"active": 0, "pad": {"t": 50}, "steps": [{"args": [{"marker.color": [["red", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 0", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "red", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 1", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "red", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 2", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "#B0BEC5", "red", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 3", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "red", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 4", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "red", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 5", "method": "update"}, {"args": [{"marker.color": [["#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "#B0BEC5", "red", "#B0BEC5", "#B0BEC5", "#B0BEC5"]]}], "label": "Topic 6", "method": "update"}, {"args": [{"marker.color": [[" ...

# %%
topic_model.visualize_topics()
# Out:
# <div>                            <div id="79090253-6abf-4ade-ada3-8248f3f90c39" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79090253-6abf-4ade-ada3-8248f3f90c39")) {                    Plotly.newPlot(                        "79090253-6abf-4ade-ada3-8248f3f90c39",                        [{"customdata": [[0, "student | school | education | teacher | class", 2867], [1, "police | suicide | body | murder | found", 2269], [2, "bjp | party | candidate | congress | leader", 1233], [3, "railway | train | passenger | station | metro", 1092], [4, " |  |  |  | ", 905], [5, "driver | accident | car | bus | truck", 841], [6, "water | supply | dam | drinking | pipeline", 786], [7, "music | song | singer | dance | classical", 773], [8, "girl | police | accused | raped | woman", 752], [9, "court | justice | bench | judge | high", 740], [10, "student | university | college | campus | hostel", 734], [11, "film | theatre | movie | actor | play", 673], [12, "flight | airport | airline | passenger | air", 630], [13, "film | actor | director | movie | shooting", 549], [14, "temperature | degree | rainfall | rain | recorded", 530], [15, "skin | diet | food | yoga | hair", 463], [16, "power | electricity | solar | energy | consumer", 458], [17, "round | championship | game | tournament | medal", 456], [18, "polling | voter | election | booth | electoral", 435], [19, "hospital | patient | cancer | oxygen | health", 387], [20, "bus | transport | route | fare | service", 370], [21, "farmer | crop | sugar | agriculture | sugarcane", 356], [22, "love | feel | var | likely | help", 355], [23, "case | reported | death | patient | active", 351], [24, "fire | building | broke | brigade | safety", 350], [25, "land | housing | estate | developer | property", 345], [26, "flood | disaster | rain | heavy | water", 345], [27, "tax | gst | income | property | crore", 340], [28, "pakistan | pakistani | taliban | musharraf | terrorist", 336], [29, "protest | farmer | police | protester | activist", 332], [30, "fisherman | boat | fish | port | vessel", 323], [31, "bridge | road | flyover | highway | traffic", 317], [32, "medical | doctor | college | seat | admission", 317], [33, "police | station | cop | camera | officer", 307], [34, "tourism | tourist | beach | hotel | destination", 306], [35, "waste | plastic | garbage | bag | dumping", 285], [36, "traffic | road | accident | vehicle | helmet", 283], [37, "bail | court | accused | plea | trial", 281], [38, "gas | oil | price | petrol | diesel", 280], [39, "maoist | force | police | rebel | nepal", 278], [40, "nuclear | china | chinese | tibetan | india", 271], [41, "cricket | wicket | ball | test | bowler", 271], [42, "building | demolition | construction | illegal | structure", 271], [43, "stock | sensex | market | index | investor", 269], [44, "telangana | trs | reddy | tdp | party", 268], [45, "card | cyber | ration | bank | account", 268], [46, "football | match | player | coach | league", 267], [47, "congress | rahul | gandhi | modi | party", 266], [48, "liquor | excise | bar | bottle | wine", 265], [49, "vaccination | vaccine | dos | vaccinated | health", 265], [50, "idol | puja | durga | festival | ganesh", 264], [51, "tree | forest | sapling | green | planted", 258], [52, "swine | flu | tested | positive | patient", 256], [53, "tiger | forest | leopard | elephant | wildlife", 255], [54, "blast | terror | bomb | terrorist | security", 252], [55, "heritage | monument | temple | site | fort", 246], [56, "worker | wage | government | pension | scheme", 241], [57, "baby | hospital | ambulance | doctor | health", 237], [58, "tata | car | company | sale | unit", 223], [59, "parking | space | vehicle | footpath | parked", 217], [60, "mining | coal | sand | mine | illegal", 213], ...

# %% [markdown]
# ### Visualize docs

# %%
# timestamps = sample_df.date.values
train_df['date'] = pd.to_datetime(train_df['date'])
# topics_over_time_df1 = topic_model.topics_over_time(texts, train_df.date.values, nr_bins=20)
# topics_over_time_grp = topics_over_time_df.groupby(['Timestamp', 'Topic']).agg('sum').reset_index()
# topics_over_time_grp = topics_over_time_grp.set_index('Timestamp')
# topics_over_time_grp

# %%
# topic_model.visualize_topics_over_time(topics_over_time_df, top_n_topics=10)

# %%
topic_model.visualize_distribution(probs[2], min_probability=0.005)
# Out:
# <div>                            <div id="7a03ae48-c737-438d-a7f2-f553b31a181e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7
class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("569efbe0-d42e-4f19-b51e-110eb39ecce2")) {                    Plotly.newPlot(                        "569efbe0-d42e-4f19-b51e-110eb39ecce2",                        [{"marker": {"color": "#D55E00"}, "orientation": "h", "type": "bar", "x": [0.01946377855943508, 0.01971481970238343, 0.024372261210009467, 0.03597031157304415, 0.03892731824714604], "xaxis": "x", "y": ["class  ", "teacher  ", "education  ", "school  ", "student  "], "yaxis": "y"}, {"marker": {"color": "#0072B2"}, "orientation": "h", "type": "bar", "x": [0.015468653622140241, 0.016003931441059296, 0.01667913074176527, 0.01713763986379498, 0.029897111383868805], "xaxis": "x2", "y": ["found  ", "murder  ", "body  ", "suicide  ", "police  "], "yaxis": "y2"}, {"marker": {"color": "#CC79A7"}, "orientation": "h", "type": "bar", "x": [0.01956974568198429, 0.022748211118080026, 0.023431123955681667, 0.0343078326737572, 0.036934912653007315], "xaxis": "x3", "y": ["leader  ", "congress  ", "candidate  ", "party  ", "bjp  "], "yaxis": "y3"}, {"marker": {"color": "#E69F00"}, "orientation": "h", "type": "bar", "x": [0.026237321364041874, 0.027700883801642033, 0.027772789866171578, 0.06960111888303017, 0.07257632112767512], "xaxis": "x4", "y": ["metro  ", "station  ", "passenger  ", "train  ", "railway  "], "yaxis": "y4"}, {"marker": {"color": "#56B4E9"}, "orientation": "h", "type": "bar", "x": [1e-05, 1e-05, 1e-05, 1e-05, 1e-05], "xaxis": "x5", "y": ["  ", "  ", "  ", "  ", "  "], "yaxis": "y5"}, {"marker": {"color": "#009E73"}, "orientation": "h", "type": "bar", "x": [0.028603489698731964, 0.03043545867604373, 0.03269389349893573, 0.037559553798491074, 0.04000253194236874], "xaxis": "x6", "y": ["truck  ", "bus  ", "car  ", "accident  ", "driver  "], "yaxis": "y6"}, {"marker": {"color": "#F0E442"}, "orientation": "h", "type": "bar", "x": [0.014067481543182422, 0.01804757802717773, 0.025218561594713914, 0.03148074454684225, 0.10761003738673713], "xaxis": "x7", "y": ["pipeline  ", "drinking  ", "dam  ", "supply  ", "water  "], "yaxis": "y7"}, {"marker": {"color": "#D55E00"}, "orientation": "h", "type": "bar", "x": [0.01700692231163514, 0.017284969916592438, 0.021544735761949388, 0.041058276263912244, 0.058027410505935816], "xaxis": "x8", "y": ["classical  ", "dance  ", "singer  ", "song  ", "music  "], "yaxis": "y8"}, {"marker": {"color": "#0072B2"}, "orientation": "h", "type": "bar", "x": [0.020291626995670414, 0.023308076525733745, 0.025719095852967437, 0.03573733450125477, 0.05003894581564392], "xaxis": "x9", "y": ["woman  ", "raped  ", "accused  ", "police  ", "girl  "], "yaxis": "y9"}, {"marker": {"color": "#CC79A7"}, "orientation": "h", "type": "bar", "x": [0.02196339065416874, 0.024032934936953288, 0.02924177074254627, 0.03704840977375982, 0.04603797537439857], "xaxis": "x10", "y": ["high  ", "judge  ", "bench  ", "justice  ", "court  "], "yaxis": "y10"}, {"marker": {"color": "#E69F00"}, "orientation": "h", "type": "bar", "x": [0.012845403380100285, 0.014743543070967705, 0.03723438726333294, 0.04435211190582581, 0.045476509790141235], "xaxis": "x11", "y": ["hostel  ", "campus  ", "college  ", "university  ", "student  "], "yaxis": "y11"}, {"marker": {"color": "#56B4E9"}, "orientation": "h", "type": "bar", "x": [0.
_loan_rate", "92_gold_diamond_jewellery", "98_currency_atm_note"], "xaxis": "x", "y": ["0_student_school_education", "7_music_song_singer", "10_student_university_college", "30_fisherman_boat_fish", "34_tourism_tourist_beach", "50_idol_puja_durga", "55_heritage_monument_temple", "70_art_artist_painting", "83_book_writer_literary", "93_temple_devotee_pilgrim", "1_police_suicide_body", "5_driver_accident_car", "23_case_reported_death", "58_tata_car_company", "74_police_gold_stolen", "77_gold_jewellery_house", "2_bjp_party_candidate", "29_protest_farmer_police", "39_maoist_force_police", "40_nuclear_china_chinese", "44_telangana_trs_reddy", "47_congress_rahul_gandhi", "54_blast_terror_bomb", "80_aircraft_defence_missile", "87_dmk_aiadmk_st ...

# %% [markdown]
# ### Topic Search by Keywords

# %%
# search topics
similar_topics, similarity = topic_model.find_topics('motor', top_n=5)
topic_model.get_topic(similar_topics[0])
# Out:
# [('tata', 0.04521627565117509),
#  ('car', 0.04186881754287438),
#  ('company', 0.031300275705048335),
#  ('sale', 0.026205593019733166),
#  ('unit', 0.023558328475499553),
#  ('steel', 0.020340474994880165),
#  ('motor', 0.019895529334124126),
#  ('market', 0.01980425403925737),
#  ('vehicle', 0.017546050785513974),
#  ('maruti', 0.016655999674796335)]

# %%
similar_topics, similarity = topic_model.find_topics('corruption', top_n=5)
topic_model.get_topic(similar_topics[0])
# Out:
# [('cbi', 0.05620954619884173),
#  ('bribe', 0.05444167180987892),
#  ('acb', 0.0405245293188542),
#  ('accepting', 0.029880981439713288),
#  ('accused', 0.024220544944546365),
#  ('bureau', 0.02015571643153948),
#  ('court', 0.019738911125192226),
#  ('arrested', 0.019024020349022043),
#  ('case', 0.01806385685928585),
#  ('caught', 0.017553793546657148)]

# %%
similar_topics, similarity = topic_model.find_topics('scam', top_n=5)
topic_model.get_topic(similar_topics[0])
# Out:
# [('currency', 0.08373534531652686),
#  ('atm', 0.08319298615489658),
#  ('note', 0.0691676578297129),
#  ('bank', 0.059323629880753244),
#  ('fake', 0.0437623812128182),
#  ('cash', 0.03879626764482015),
#  ('counterfeit', 0.03111924327907874),
#  ('denomination', 0.02118457243845715),
#  ('coin', 0.02093649069952777),
#  ('branch', 0.01872912906314579)]

# %%
similar_topics, similarity = topic_model.find_topics('gandhi', top_n=5)
topic_model.get_topic(similar_topics[0])
# Out:
# [('congress', 0.052220964696091804),
#  ('rahul', 0.03712823404357182),
#  ('gandhi', 0.03363534228761747),
#  ('modi', 0.027232265110904444),
#  ('party', 0.026454293023728283),
#  ('sonia', 0.021688830920645948),
#  ('leader', 0.020473956032085086),
#  ('bjp', 0.017811474072415137),
#  ('prime', 0.015245430666849375),
#  ('minister', 0.015166130823978084)]

# %% [markdown]
# ### Save the topic model for future use

# %%
if model_trained != 'Y':
    torch.save(topic_model, '/home/amitjha/bertopic_model_3pc')
    train_df.to_csv('train_df_3pc.csv')

# %% [markdown]
# ### Topic Inference

# %%
# %%time
articles_df = topic_inference(basepath,model_path, topic_model)
# Out:
# CPU times: user 7 µs, sys: 1e+03 ns, total: 8 µs
# Wall time: 6.91 µs
